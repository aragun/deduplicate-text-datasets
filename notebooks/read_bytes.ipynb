# %%
cache = '/home/anuragik/data/staging/cache/'

import glob
# import codex

for file in glob.glob(cache + 'sizes*'):
    with open(file, "rb") as f:
        for x in f:
            print(f"x = {x}")
            print(int.from_bytes(x, byteorder='big'))
# Out:
# x = b'\x03\x04\x04'
# 197636
# x = b'\x04'
# 4
# x = b'\x04\x04\x03'
# 263171
# x = b'\x03'
# 3
# x = b'\x04'
# 4
# x = b'\x04\x04'
# 1028
# x = b'\x04\x04'
# 1028
# x = b'\x03\x03'
# 771
# x = b'\x04\x04'
# 1028
# x = b'\x03'
# 3
# x = b'\x04'
# 4
# x = b'\x03'
# 3
# x = b'\x04'
# 4
# x = b'\x04\x04\x03'
# 263171
# x = b'\x03'
# 3
# x = b'\x03\x03'
# 771
# x = b'\x04'
# 4
# x = b'\x03\x04\x04\x03'
# 50594819
# x = b'\x03'
# 3
# x = b'\x04\x03'
# 1027
# x = b'\x04\x03'
# 1027
# x = b'\x04\x04\x03'
# 263171
# x = b'\x04'
# 4
# x = b'\x04\x03'
# 1027
# x = b'\x03\x04\x03'
# 197635
# x = b'\x04\x03'
# 1027
# x = b'\x04\x03\x03'
# 262915
# x = b'\x03\x04'
# 772
# x = b'\x03'
# 3
# x = b'\x04\x03\x04'
# 262916
# x = b'\x03\x03'
# 771
# x = b'\x04\x04\x04'
# 263172
# x = b'\x04\x04'
# 1028
# x = b'\x03'
# 3
# x = b'\x04\x03'
# 1027
# x = b'\x04\x03'
# 1027
# x = b'\x03\x04'
# 772
# x = b'\x04\x03'
# 1027
# x = b'\x03\x03'
# 771
# x = b'\x04'
# 4
# x = b'\x04\x03\x04'
# 262916
# ...
